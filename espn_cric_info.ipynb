# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("espn cric info.csv")

# %%
df.head()
# Out:
#              Player       Span Mat  Inns    NO    Runs    HS    Ave     BF  \
# 0  DG Bradman (AUS)  1928-1948  52  80.0  10.0  6996.0   334  99.94  9800+
# 1    AC Voges (AUS)  2015-2016  20  31.0   7.0  1485.0  269*  61.87   2667
# 2   RG Pollock (SA)  1963-1970  23  41.0   4.0  2256.0   274  60.97  1707+
# 3   GA Headley (WI)  1930-1954  22  40.0   4.0  2190.0  270*  60.83   416+
# 4   GA Headley (WI)  1930-1954  22  40.0   4.0  2190.0  270*  60.83   416+
#
#       SR   100    50    0    4s  6s
# 0  58.60  29.0  13.0  7.0  626+   6
# 1  55.68   5.0   4.0  2.0   186   5
# 2  54.48   7.0  11.0  1.0  246+  11
# 3  56.00  10.0   5.0  2.0  104+   1
# 4  56.00  10.0   5.0  2.0  104+   1

# %%
df=df.rename(columns={'NO':'Not_outs','HS':'Highest_Inns_Score','BF':'Balls_Faced','SR':'Batting_Strike_Rate'})

# %%
df.head()
# Out:
#              Player       Span Mat  Inns  Not_outs    Runs Highest_Inns_Score  \
# 0  DG Bradman (AUS)  1928-1948  52  80.0      10.0  6996.0                334
# 1    AC Voges (AUS)  2015-2016  20  31.0       7.0  1485.0               269*
# 2   RG Pollock (SA)  1963-1970  23  41.0       4.0  2256.0                274
# 3   GA Headley (WI)  1930-1954  22  40.0       4.0  2190.0               270*
# 4   GA Headley (WI)  1930-1954  22  40.0       4.0  2190.0               270*
#
#      Ave Balls_Faced  Batting_Strike_Rate   100    50    0    4s  6s
# 0  99.94       9800+                58.60  29.0  13.0  7.0  626+   6
# 1  61.87        2667                55.68   5.0   4.0  2.0   186   5
# 2  60.97       1707+                54.48   7.0  11.0  1.0  246+  11
# 3  60.83        416+                56.00  10.0   5.0  2.0  104+   1
# 4  60.83        416+                56.00  10.0   5.0  2.0  104+   1

# %%
df.isnull().any()
# Out:
# Player                 True
# Span                   True
# Mat                    True
# Inns                   True
# Not_outs               True
# Runs                   True
# Highest_Inns_Score     True
# Ave                    True
# Balls_Faced            True
# Batting_Strike_Rate    True
# 100                    True
# 50                     True
# 0                      True
# 4s                     True
# 6s                     True
# dtype: bool

# %%
df[df['Balls_Faced'].isna()==1]
# Out:
#                                                Player       Span  \
# 9                                      ED Weekes (WI)  1948-1958
# 16                                    CL Walcott (WI)  1948-1960
# 65  Adjust:Most recentPast weekPast MonthPast year...        NaN
# 66                                                NaN        NaN
# 67                                                NaN        NaN
#
#                                                   Mat  Inns  Not_outs    Runs  \
# 9                                                  48  81.0       5.0  4455.0
# 16                                                 44  74.0       7.0  3798.0
# 65                                                NaN   NaN       NaN     NaN
# 66                                                NaN   NaN       NaN     NaN
# 67  Adjust:Most recentPast weekPast MonthPast year...   NaN       NaN     NaN
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate   100    50  \
# ...

# %%
df
# Out:
#                                                Player       Span  \
# 0                                    DG Bradman (AUS)  1928-1948
# 1                                      AC Voges (AUS)  2015-2016
# 2                                     RG Pollock (SA)  1963-1970
# 3                                     GA Headley (WI)  1930-1954
# 4                                     GA Headley (WI)  1930-1954
# 5                                   H Sutcliffe (ENG)  1924-1935
# 6                                      HC Brook (ENG)  2022-2024
# 7                                     E Paynter (ENG)  1931-1939
# 8                                 KF Barrington (ENG)  1955-1968
# 9                                      ED Weekes (WI)  1948-1958
# 10                                   WR Hammond (ENG)  1927-1947
# 11                                     GS Sobers (WI)  1954-1974
# 12                                 KC Sangakkara (SL)  2000-2015
# ...

# %%
df = df.drop(df.tail(3).index)

# %%
df
# Out:
#                       Player       Span  Mat   Inns  Not_outs     Runs  \
# 0           DG Bradman (AUS)  1928-1948   52   80.0      10.0   6996.0
# 1             AC Voges (AUS)  2015-2016   20   31.0       7.0   1485.0
# 2            RG Pollock (SA)  1963-1970   23   41.0       4.0   2256.0
# 3            GA Headley (WI)  1930-1954   22   40.0       4.0   2190.0
# 4            GA Headley (WI)  1930-1954   22   40.0       4.0   2190.0
# 5          H Sutcliffe (ENG)  1924-1935   54   84.0       9.0   4555.0
# 6             HC Brook (ENG)  2022-2024   15   24.0       1.0   1378.0
# 7            E Paynter (ENG)  1931-1939   20   31.0       5.0   1540.0
# 8        KF Barrington (ENG)  1955-1968   82  131.0      15.0   6806.0
# 9             ED Weekes (WI)  1948-1958   48   81.0       5.0   4455.0
# 10          WR Hammond (ENG)  1927-1947   85  140.0      16.0   7249.0
# 11            GS Sobers (WI)  1954-1974   93  160.0      21.0   8032.0
# ...

# %%
df.isnull().any()
# Out:
# Player                 False
# Span                   False
# Mat                    False
# Inns                   False
# Not_outs               False
# Runs                   False
# Highest_Inns_Score     False
# Ave                    False
# Balls_Faced             True
# Batting_Strike_Rate     True
# 100                    False
# 50                     False
# 0                      False
# 4s                     False
# 6s                     False
# dtype: bool

# %%
df[df['Balls_Faced'].isna()==1]
# Out:
#              Player       Span Mat  Inns  Not_outs    Runs Highest_Inns_Score  \
# 9    ED Weekes (WI)  1948-1958  48  81.0       5.0  4455.0                207
# 16  CL Walcott (WI)  1948-1960  44  74.0       7.0  3798.0                220
#
#       Ave Balls_Faced  Batting_Strike_Rate   100    50    0    4s  6s
# 9   58.61         NaN                  NaN  15.0  19.0  6.0  258+   2
# 16  56.68         NaN                  NaN  15.0  14.0  1.0  107+  11

# %%
df['Balls_Faced']=df['Balls_Faced'].fillna(0)

# %%
df['Batting_Strike_Rate']=df['Batting_Strike_Rate'].fillna(0)

# %%
df[df['Player']=='CL Walcott (WI)']
# Out:
#              Player       Span Mat  Inns  Not_outs    Runs Highest_Inns_Score  \
# 16  CL Walcott (WI)  1948-1960  44  74.0       7.0  3798.0                220
#
#       Ave Balls_Faced  Batting_Strike_Rate   100    50    0    4s  6s
# 16  56.68           0                  0.0  15.0  14.0  1.0  107+  11

# %%
df[df.duplicated()]
# Out:
#              Player       Span  Mat   Inns  Not_outs    Runs  \
# 4   GA Headley (WI)  1930-1954   22   40.0       4.0  2190.0
# 15   JB Hobbs (ENG)  1908-1930   61  102.0       7.0  5410.0
# 53    V Kohli (IND)  2011-2024  113  191.0      11.0  8848.0
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate   100    50  \
# 4                270*  60.83        416+                56.00  10.0   5.0
# 15                211  56.94       5363+                46.22  15.0  28.0
# 53               254*  49.15       15924                55.56  29.0  30.0
#
#        0    4s  6s
# 4    2.0  104+   1
# 15   4.0  276+   8
# 53  14.0   991  26

# %%
df[df['Player'].isin(['GA Headley (WI)','JB Hobbs (ENG)','V Kohli (IND)'])]
# Out:
#              Player       Span  Mat   Inns  Not_outs    Runs  \
# 3   GA Headley (WI)  1930-1954   22   40.0       4.0  2190.0
# 4   GA Headley (WI)  1930-1954   22   40.0       4.0  2190.0
# 14   JB Hobbs (ENG)  1908-1930   61  102.0       7.0  5410.0
# 15   JB Hobbs (ENG)  1908-1930   61  102.0       7.0  5410.0
# 52    V Kohli (IND)  2011-2024  113  191.0      11.0  8848.0
# 53    V Kohli (IND)  2011-2024  113  191.0      11.0  8848.0
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate   100    50  \
# 3                270*  60.83        416+                56.00  10.0   5.0
# 4                270*  60.83        416+                56.00  10.0   5.0
# 14                211  56.94       5363+                46.22  15.0  28.0
# 15                211  56.94       5363+                46.22  15.0  28.0
# 52               254*  49.15       15924                55.56  29.0  30.0
# 53               254*  49.15       15924                55.56  29.0  30.0
#
# ...

# %%
df=df.drop_duplicates()

# %%
df['Span'].str.split('-')
# Out:
# 0     [1928, 1948]
# 1     [2015, 2016]
# 2     [1963, 1970]
# 3     [1930, 1954]
# 5     [1924, 1935]
# 6     [2022, 2024]
# 7     [1931, 1939]
# 8     [1955, 1968]
# 9     [1948, 1958]
# 10    [1927, 1947]
# 11    [1954, 1974]
# 12    [2000, 2015]
# 13    [2010, 2024]
# 14    [1908, 1930]
# 16    [1948, 1960]
# 17    [1937, 1955]
# 18    [1995, 2013]
# 19    [1921, 1929]
# 20    [2010, 2024]
# 21    [1968, 1973]
# 22    [1993, 1995]
# 23    [1970, 1984]
# 24    [1935, 1951]
# 25    [1989, 2013]
# 26    [1990, 2006]
# 27    [1976, 1993]
# 28    [1996, 2012]
# 29    [1998, 2010]
# 30    [2000, 2017]
# 31    [1995, 2012]
# 32    [1920, 1929]
# 33    [1992, 2002]
# 34    [2005, 2013]
# 35    [1994, 2015]
# 36    [1971, 1987]
# 37    [1985, 2004]
# 38    [1994, 2009]
# 39    [2004, 2018]
# 40    [1978, 1994]
# 41    [2019, 2024]
# 42    [1974, 1991]
# 43    [2012, 2024]
# 44    [1937, 1957]
# 45    [1997, 2014]
# 46    [1992, 2007]
# 47    [2018, 2024]
# 48    [1948, 1963]
# ...

# %%
df['Rookie_Year']=df['Span'].str.split(pat='-').str[0]
# Out:
# /var/folders/l5/8bs6zkc17b188xlxsd97wkd40000gn/T/ipykernel_1354/1740907504.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Rookie_Year']=df['Span'].str.split(pat='-').str[0]

# %%
df['Final_Year']=df['Span'].str.split(pat='-').str[1]
# Out:
# /var/folders/l5/8bs6zkc17b188xlxsd97wkd40000gn/T/ipykernel_1354/1405677318.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Final_Year']=df['Span'].str.split(pat='-').str[1]

# %%
df.drop(['Span'],axis=1,inplace=True)
# Out:
# /var/folders/l5/8bs6zkc17b188xlxsd97wkd40000gn/T/ipykernel_1354/1412154912.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(['Span'],axis=1,inplace=True)

# %%
df['Player'].str.split(pat='(')
# Out:
# 0             [DG Bradman , AUS)]
# 1               [AC Voges , AUS)]
# 2              [RG Pollock , SA)]
# 3              [GA Headley , WI)]
# 5            [H Sutcliffe , ENG)]
# 6               [HC Brook , ENG)]
# 7              [E Paynter , ENG)]
# 8          [KF Barrington , ENG)]
# 9               [ED Weekes , WI)]
# 10            [WR Hammond , ENG)]
# 11              [GS Sobers , WI)]
# 12          [KC Sangakkara , SL)]
# 13             [SPD Smith , AUS)]
# 14              [JB Hobbs , ENG)]
# 16             [CL Walcott , WI)]
# 17              [L Hutton , ENG)]
# 18          [JH Kallis , ICC/SA)]
# 19          [GE Tyldesley , ENG)]
# 20          [KS Williamson , NZ)]
# 21               [CA Davis , WI)]
# 22             [VG Kambli , IND)]
# 23           [GS Chappell , AUS)]
# 24              [AD Nourse , SA)]
# 25          [SR Tendulkar , IND)]
# 26            [BC Lara , ICC/WI)]
# 27         [Javed Miandad , PAK)]
# 28          [R Dravid , ICC/IND)]
# ...

# %%
df['Country']=df['Player'].str.split(pat='(').str[1]
# Out:
# /var/folders/l5/8bs6zkc17b188xlxsd97wkd40000gn/T/ipykernel_1354/2799593456.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country']=df['Player'].str.split(pat='(').str[1]

# %%
df['Country']=df['Country'].str.split(pat=')').str[0]
# Out:
# /var/folders/l5/8bs6zkc17b188xlxsd97wkd40000gn/T/ipykernel_1354/1791978499.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country']=df['Country'].str.split(pat=')').str[0]

# %%
df['Country']
# Out:
# 0         AUS
# 1         AUS
# 2          SA
# 3          WI
# 5         ENG
# 6         ENG
# 7         ENG
# 8         ENG
# 9          WI
# 10        ENG
# 11         WI
# 12         SL
# 13        AUS
# 14        ENG
# 16         WI
# 17        ENG
# 18     ICC/SA
# 19        ENG
# 20         NZ
# 21         WI
# 22        IND
# 23        AUS
# 24         SA
# 25        IND
# 26     ICC/WI
# 27        PAK
# 28    ICC/IND
# 29        PAK
# 30        PAK
# 31        AUS
# 32        AUS
# 33        ZIM
# 34        AUS
# 35         WI
# 36        IND
# 37        AUS
# 38        AUS
# 39         SA
# 40        AUS
# 41         NZ
# 42         WI
# 43        ENG
# 44        ENG
# 45         SL
# 46    ICC/PAK
# 47        AUS
# 48         WI
# 49        ENG
# 50    ICC/IND
# 51        PAK
# 52        IND
# 54        AUS
# 55         SA
# 56         SA
# 57        ENG
# 58         SL
# 59        AUS
# 60        AUS
# 61     ICC/SA
# 62        AUS
# 63        AUS
# 64        ENG
# ...

# %%
df['Player']=df['Player'].str.split(pat='(').str[0]
# Out:
# /var/folders/l5/8bs6zkc17b188xlxsd97wkd40000gn/T/ipykernel_1354/3262409920.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Player']=df['Player'].str.split(pat='(').str[0]

# %%
df
# Out:
#                Player  Mat   Inns  Not_outs     Runs Highest_Inns_Score  \
# 0         DG Bradman    52   80.0      10.0   6996.0                334
# 1           AC Voges    20   31.0       7.0   1485.0               269*
# 2         RG Pollock    23   41.0       4.0   2256.0                274
# 3         GA Headley    22   40.0       4.0   2190.0               270*
# 5        H Sutcliffe    54   84.0       9.0   4555.0                194
# 6           HC Brook    15   24.0       1.0   1378.0                186
# 7          E Paynter    20   31.0       5.0   1540.0                243
# 8      KF Barrington    82  131.0      15.0   6806.0                256
# 9          ED Weekes    48   81.0       5.0   4455.0                207
# 10        WR Hammond    85  140.0      16.0   7249.0               336*
# 11         GS Sobers    93  160.0      21.0   8032.0               365*
# 12     KC Sangakkara   134  233.0      17.0  12400.0                319
# ...

# %%
df.dtypes
# Out:
# Player                  object
# Mat                     object
# Inns                   float64
# Not_outs               float64
# Runs                   float64
# Highest_Inns_Score      object
# Ave                    float64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                    float64
# 50                     float64
# 0                      float64
# 4s                      object
# 6s                      object
# Rookie_Year             object
# Final_Year              object
# Country                 object
# dtype: object

# %%
df['Highest_Inns_Score']=df['Highest_Inns_Score'].str.split(pat='*').str[0]
df['Highest_Inns_Score']
# Out:
# /var/folders/l5/8bs6zkc17b188xlxsd97wkd40000gn/T/ipykernel_1354/859317725.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Highest_Inns_Score']=df['Highest_Inns_Score'].str.split(pat='*').str[0]
# 0     334
# 1     269
# 2     274
# 3     270
# 5     194
# 6     186
# 7     243
# 8     256
# 9     207
# 10    336
# 11    365
# 12    319
# 13    239
# 14    211
# 16    220
# 17    364
# 18    224
# 19    122
# 20    251
# 21    183
# 22    227
# 23    247
# 24    231
# 25    248
# 26    400
# 27    280
# 28    270
# 29    223
# 30    313
# 31    257
# 32    201
# 33    232
# 34    195
# 35    203
# 36    236
# 37    200
# 38    380
# 39    278
# 40    205
# 41    190
# 42    291
# 43    254
# 44    278
# 45    374
# 46    329
# ...

# %%
df['Highest_Inns_Score']=df['Highest_Inns_Score'].astype('int')
# Out:
# /var/folders/l5/8bs6zkc17b188xlxsd97wkd40000gn/T/ipykernel_1354/3377248302.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Highest_Inns_Score']=df['Highest_Inns_Score'].astype('int')

# %%
df.dtypes
# Out:
# Player                  object
# Mat                     object
# Inns                   float64
# Not_outs               float64
# Runs                   float64
# Highest_Inns_Score       int64
# Ave                    float64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                    float64
# 50                     float64
# 0                      float64
# 4s                      object
# 6s                      object
# Rookie_Year             object
# Final_Year              object
# Country                 object
# dtype: object

# %%
df=df.astype({'Rookie_Year':'int','Final_Year':'int','Mat':'int'})

# %%
df['Balls_Faced']=df['Balls_Faced'].str.split(pat='+').str[0]

# %%
df['Balls_Faced']=df['Balls_Faced'].fillna(0)

# %%
df['Balls_Faced']=df['Balls_Faced'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[151], line 1
# ----> 1 df['Balls_Faced']=df['Balls_Faced'].astype('int')
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/internals/managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# ...

# %%
pd.set_option('display.max_rows',None)

# %%
df
# Out:
#                Player  Mat   Inns  Not_outs     Runs  Highest_Inns_Score  \
# 0         DG Bradman    52   80.0      10.0   6996.0                 334
# 1           AC Voges    20   31.0       7.0   1485.0                 269
# 2         RG Pollock    23   41.0       4.0   2256.0                 274
# 3         GA Headley    22   40.0       4.0   2190.0                 270
# 5        H Sutcliffe    54   84.0       9.0   4555.0                 194
# 6           HC Brook    15   24.0       1.0   1378.0                 186
# 7          E Paynter    20   31.0       5.0   1540.0                 243
# 8      KF Barrington    82  131.0      15.0   6806.0                 256
# 9          ED Weekes    48   81.0       5.0   4455.0                 207
# 10        WR Hammond    85  140.0      16.0   7249.0                 336
# 11         GS Sobers    93  160.0      21.0   8032.0                 365
# 12     KC Sangakkara   134  233.0      17.0  12400.0                 319
# ...

# %%
df.drop(57,axis=0,inplace=True)

# %%
df['Balls_Faced']=df['Balls_Faced'].astype('int')

# %%
df.dtypes
# Out:
# Player                  object
# Mat                      int64
# Inns                   float64
# Not_outs               float64
# Runs                   float64
# Highest_Inns_Score       int64
# Ave                    float64
# Balls_Faced              int64
# Batting_Strike_Rate    float64
# 100                    float64
# 50                     float64
# 0                      float64
# 4s                      object
# 6s                      object
# Rookie_Year              int64
# Final_Year               int64
# Country                 object
# dtype: object

# %%
df['Balls_Faced']=df['Balls_Faced'].astype('int')

# %%
df['Career_Length']=df['Final_Year']-df['Rookie_Year']

# %%
df
# Out:
#                Player  Mat   Inns  Not_outs     Runs  Highest_Inns_Score  \
# 0         DG Bradman    52   80.0      10.0   6996.0                 334
# 1           AC Voges    20   31.0       7.0   1485.0                 269
# 2         RG Pollock    23   41.0       4.0   2256.0                 274
# 3         GA Headley    22   40.0       4.0   2190.0                 270
# 5        H Sutcliffe    54   84.0       9.0   4555.0                 194
# 6           HC Brook    15   24.0       1.0   1378.0                 186
# 7          E Paynter    20   31.0       5.0   1540.0                 243
# 8      KF Barrington    82  131.0      15.0   6806.0                 256
# 9          ED Weekes    48   81.0       5.0   4455.0                 207
# 10        WR Hammond    85  140.0      16.0   7249.0                 336
# 11         GS Sobers    93  160.0      21.0   8032.0                 365
# 12     KC Sangakkara   134  233.0      17.0  12400.0                 319
# ...

# %%
#avg carrer length
df['Career_Length'].mean()
# Out:
# 13.229508196721312

# %%
df[df['Career_Length']>10]['Batting_Strike_Rate'].mean()
# Out:
# 49.06627906976744

# %%
df[df['Rookie_Year']<1960]['Player'].count()
# Out:
# 22

# %%
df.groupby('Country')['Highest_Inns_Score'].max().to_frame('Highest_Inns_Score').reset_index().sort_values('Highest_Inns_Score',ascending=False)
# Out:
#     Country  Highest_Inns_Score
# 5    ICC/WI                 400
# 0       AUS                 380
# 10       SL                 374
# 11       WI                 365
# 1       ENG                 364
# 3   ICC/PAK                 329
# 2   ICC/IND                 319
# 8       PAK                 313
# 9        SA                 278
# 4    ICC/SA                 277
# 6       IND                 254
# 7        NZ                 251
# 12      ZIM                 232

# %%
df.groupby('Country')[['100','50','0']].mean()
# Out:
#                100         50          0
# Country
# AUS      20.625000  28.375000   8.562500
# ENG      13.166667  22.333333   4.416667
# ICC/IND  29.500000  47.500000  12.000000
# ICC/PAK  25.000000  46.000000  15.000000
# ICC/SA   36.000000  48.000000  13.500000
# ICC/WI   34.000000  48.000000  17.000000
# IND      29.500000  36.500000  10.750000
# NZ       18.500000  22.000000   6.000000
# PAK      21.250000  28.000000   9.500000
# SA        9.800000  20.200000   3.400000
# SL       28.666667  44.000000  12.333333
# WI       16.625000  25.625000   7.250000
# ZIM      12.000000  27.000000   5.000000

# %%
df
# Out:
#                Player  Mat   Inns  Not_outs     Runs  Highest_Inns_Score  \
# 0         DG Bradman    52   80.0      10.0   6996.0                 334
# 1           AC Voges    20   31.0       7.0   1485.0                 269
# 2         RG Pollock    23   41.0       4.0   2256.0                 274
# 3         GA Headley    22   40.0       4.0   2190.0                 270
# 5        H Sutcliffe    54   84.0       9.0   4555.0                 194
# 6           HC Brook    15   24.0       1.0   1378.0                 186
# 7          E Paynter    20   31.0       5.0   1540.0                 243
# 8      KF Barrington    82  131.0      15.0   6806.0                 256
# 9          ED Weekes    48   81.0       5.0   4455.0                 207
# 10        WR Hammond    85  140.0      16.0   7249.0                 336
# 11         GS Sobers    93  160.0      21.0   8032.0                 365
# 12     KC Sangakkara   134  233.0      17.0  12400.0                 319
# ...

# %%
plt.figure(figsize=(12, 6)) 
sns.barplot(data=df,x='Player',y='Batting_Strike_Rate',hue='Country')
plt.xticks(rotation=90)
plt.show()

# %%
df
# Out:
#                Player  Mat   Inns  Not_outs     Runs  Highest_Inns_Score  \
# 0         DG Bradman    52   80.0      10.0   6996.0                 334
# 1           AC Voges    20   31.0       7.0   1485.0                 269
# 2         RG Pollock    23   41.0       4.0   2256.0                 274
# 3         GA Headley    22   40.0       4.0   2190.0                 270
# 5        H Sutcliffe    54   84.0       9.0   4555.0                 194
# 6           HC Brook    15   24.0       1.0   1378.0                 186
# 7          E Paynter    20   31.0       5.0   1540.0                 243
# 8      KF Barrington    82  131.0      15.0   6806.0                 256
# 9          ED Weekes    48   81.0       5.0   4455.0                 207
# 10        WR Hammond    85  140.0      16.0   7249.0                 336
# 11         GS Sobers    93  160.0      21.0   8032.0                 365
# 12     KC Sangakkara   134  233.0      17.0  12400.0                 319
# ...

# %%
df['Player'] = df['Player'].str.strip()

# %%
df[df['Player']== 'CL Walcott']
# Out:
#         Player  Mat  Inns  Not_outs    Runs  Highest_Inns_Score    Ave  \
# 16  CL Walcott   44  74.0       7.0  3798.0                 220  56.68
#
#     Balls_Faced  Batting_Strike_Rate   100    50    0    4s  6s  Rookie_Year  \
# 16            0                  0.0  15.0  14.0  1.0  107+  11         1948
#
#     Final_Year Country  Career_Length
# 16        1960      WI             12

# %%
country_hundreds = df.groupby('Country')['100'].sum().sort_values(ascending=False)

# %%
country_hundreds
# Out:
# Country
# AUS        330.0
# ENG        158.0
# WI         133.0
# IND        118.0
# SL          86.0
# PAK         85.0
# ICC/SA      72.0
# ICC/IND     59.0
# SA          49.0
# NZ          37.0
# ICC/WI      34.0
# ICC/PAK     25.0
# ZIM         12.0
# Name: 100, dtype: float64

# %%
plt.figure(figsize=(8, 8))
plt.pie(country_hundreds,labels=country_hundreds.index, autopct='%1.1f%%')
plt.title('Distribution of Hundreds by Country')
plt.show()

# %%
country_innings = df.groupby('Country')['Inns'].sum().sort_values(ascending=False)

# %%
plt.figure(figsize=(8, 8))
plt.pie(country_innings,labels=country_innings.index, autopct='%1.1f%%')
plt.title('Distribution of innings by Country')
plt.show()

# %%
plt.figure(figsize=(12, 6)) 
sns.barplot(data=df,x='Player',y='Not_outs')
plt.xticks(rotation=90)
plt.show()

# %%
df
# Out:
#               Player  Mat   Inns  Not_outs     Runs  Highest_Inns_Score  \
# 0         DG Bradman   52   80.0      10.0   6996.0                 334
# 1           AC Voges   20   31.0       7.0   1485.0                 269
# 2         RG Pollock   23   41.0       4.0   2256.0                 274
# 3         GA Headley   22   40.0       4.0   2190.0                 270
# 5        H Sutcliffe   54   84.0       9.0   4555.0                 194
# 6           HC Brook   15   24.0       1.0   1378.0                 186
# 7          E Paynter   20   31.0       5.0   1540.0                 243
# 8      KF Barrington   82  131.0      15.0   6806.0                 256
# 9          ED Weekes   48   81.0       5.0   4455.0                 207
# 10        WR Hammond   85  140.0      16.0   7249.0                 336
# 11         GS Sobers   93  160.0      21.0   8032.0                 365
# 12     KC Sangakkara  134  233.0      17.0  12400.0                 319
# ...

# %%
df.to_csv('cric_info1.csv', index=False)

# %%
df['Country'].unique()
# Out:
# array(['AUS', 'SA', 'WI', 'ENG', 'SL', 'ICC/SA', 'NZ', 'IND', 'ICC/WI',
#        'PAK', 'ICC/IND', 'ZIM', 'ICC/PAK'], dtype=object)

# %%
df[df['Country']=='ICC/SA']
# Out:
#        Player  Mat   Inns  Not_outs     Runs  Highest_Inns_Score    Ave  \
# 18  JH Kallis  166  280.0      40.0  13289.0                 224  55.37
# 61   GC Smith  117  205.0      13.0   9265.0                 277  48.25
#
#     Balls_Faced  Batting_Strike_Rate   100    50     0    4s  6s  Rookie_Year  \
# 18        28903                45.97  45.0  58.0  16.0  1488  97         1995
# 61        15525                59.67  27.0  38.0  11.0  1165  24         2002
#
#     Final_Year Country  Career_Length
# 18        2013  ICC/SA             18
# 61        2014  ICC/SA             12

# %%
# List of players whose country should be changed to 'India'
players_to_update = ['R Dravid', 'V Sehwag']

# Update the 'Country' column for these players
df.loc[df['Player'].isin(players_to_update), 'Country'] = 'IND'

# %%
df[df['Country']=='IND']
# Out:
#           Player  Mat   Inns  Not_outs     Runs  Highest_Inns_Score    Ave  \
# 22     VG Kambli   17   21.0       1.0   1084.0                 227  54.20
# 25  SR Tendulkar  200  329.0      33.0  15921.0                 248  53.78
# 28      R Dravid  164  286.0      32.0  13288.0                 270  52.31
# 36   SM Gavaskar  125  214.0      16.0  10122.0                 236  51.12
# 50      V Sehwag  104  180.0       6.0   8586.0                 319  49.34
# 52       V Kohli  113  191.0      11.0   8848.0                 254  49.15
#
#     Balls_Faced  Batting_Strike_Rate   100    50     0     4s  6s  \
# 22         1823                59.46   4.0   3.0   3.0    124   6
# 25        29437                54.04  51.0  68.0  14.0  2058+  69
# 28        31258                42.51  36.0  63.0   8.0   1654  21
# 36        14184                43.35  34.0  45.0  12.0   908+  26
# 50        10441                82.23  23.0  32.0  16.0   1233  91
# ...

# %%
players_to_update = ['JH Kallis', 'GC Smith']

# Update the 'Country' column for these players
df.loc[df['Player'].isin(players_to_update), 'Country'] = 'SA'

# %%
df[df['Country']=='NZ']
# Out:
#            Player  Mat   Inns  Not_outs    Runs  Highest_Inns_Score    Ave  \
# 20  KS Williamson  100  176.0      17.0  8743.0                 251  54.98
# 41    DJ Mitchell   23   37.0       5.0  1608.0                 190  50.25
#
#     Balls_Faced  Batting_Strike_Rate   100    50     0   4s  6s  Rookie_Year  \
# 20        17006                51.41  32.0  34.0  11.0  971  24         2010
# 41         3014                53.35   5.0  10.0   1.0  158  29         2019
#
#     Final_Year Country  Career_Length
# 20        2024      NZ             14
# 41        2024      NZ              5

# %%
players_to_update = ['Inzamam-ul-Haq']

# Update the 'Country' column for these players
df.loc[df['Player'].isin(players_to_update), 'Country'] = 'PAK'

# %%
df['Country'].unique()
# Out:
# array(['AUS', 'SA', 'WI', 'ENG', 'SL', 'NZ', 'IND', 'PAK', 'ZIM'],
#       dtype=object)

# %%
df.to_csv('cric_info2.csv', index=False)
